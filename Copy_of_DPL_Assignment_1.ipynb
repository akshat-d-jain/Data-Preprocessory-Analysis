# %% [markdown]
# Importing the bs4 library through which we can use Beautiful Soup

# %% [markdown]
# # Task 1: Web Scraping using Beautiful Soup

# %%
from bs4 import BeautifulSoup
import requests
import os
from bs4 import *

# %%
url="http://quotes.toscrape.com/"
response=requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %% [markdown]
# a. Find the title tag

# %%
print(soup.title)
# Out:
# <title>Quotes to Scrape</title>

# %%
title_tag = soup.title
print(title_tag.text)
# Out:
# Quotes to Scrape

# %% [markdown]
# b. retrieve all the paragraph tags

# %%
paragraph_tags = soup.find_all("p")
for p_tag in paragraph_tags:
    print(p_tag.text)
# Out:
# Login
#
#
#                 Quotes by: GoodReads.com
#
#
#                 Made with ❤ by Zyte

# %% [markdown]
# c. extract the text in the first paragraph tag

# %%
first_paragraph_text = paragraph_tags[0].text
print(first_paragraph_text)
# Out:
# Login

# %% [markdown]
# d. Find all the h2 tags

# %%
h2tags=soup.find_all('h2')
for soups in h2tags:
  print(soups)
# Out:
# <h2>Top Ten tags</h2>

# %% [markdown]
# e. find the length of the text of the first h2 tag

# %%
len(soup.h2)
# Out:
# 1

# %%
first_h2_length = len(h2tags[0].text)
print(first_h2_length)
# Out:
# 12

# %% [markdown]
# f. find the text of the first a tag

# %%
first_a_text = soup.find("a").text
print(first_a_text)
# Out:
# Quotes to Scrape

# %% [markdown]
# g. find the href of the first a tag

# %%
first_a_href = soup.find("a")["href"]
print(first_a_href)
# Out:
# /

# %% [markdown]
# h. extract all the URLs from the webpage python.org that are nested within li
# tags

# %%
li_tags = soup.find_all("li")
urls_in_li = [li.find("a")["href"] for li in li_tags if li.find("a")]

# %%
for url in urls_in_li:
    print(url)
# Out:
# /page/2/

# %% [markdown]
# # 2. Getting started with "https://www.python.org"

# %%
python_org_url = "https://www.python.org"
response_python_org = requests.get(python_org_url)
print(response_python_org)
# Out:
# <Response [200]>

# %% [markdown]
# 3.Get the page https://www.python.org/ via functionality provided in the requests
# module in Python.

# %% [markdown]
# 4. From the html website, write a Python program to do the following tasks:
# a. extract all the URLs that are nested within li tags

# %%
python_org_url = "https://www.python.org"
response_python_org = requests.get(python_org_url)
print(response_python_org)
# Out:
# <Response [200]>

# %%
soup_python_org = BeautifulSoup(response_python_org.text, "html.parser")

# %%
li_tags = soup_python_org.find_all("li")
urls_in_li = [li.find("a")["href"] for li in li_tags if li.find("a")]

# %%
for url in urls_in_li:
    print(url)
# Out:
# /
# https://www.python.org/psf/
# https://docs.python.org
# https://pypi.org/
# /jobs/
# /community-landing/
# #
# javascript:;
# javascript:;
# javascript:;
# #
# https://www.facebook.com/pythonlang?fref=ts
# https://twitter.com/ThePSF
# /community/irc/
# /about/
# /about/apps/
# /about/quotes/
# /about/gettingstarted/
# /about/help/
# http://brochure.getpython.info/
# /downloads/
# /downloads/
# /downloads/source/
# /downloads/windows/
# /downloads/macos/
# /download/other/
# https://docs.python.org/3/license.html
# /download/alternatives
# /doc/
# /doc/
# /doc/av
# https://wiki.python.org/moin/BeginnersGuide
# https://devguide.python.org/
# https://docs.python.org/faq/
# http://wiki.python.org/moin/Languages
# http://python.org/dev/peps/
# https://wiki.python.org/moin/PythonBooks
# /doc/essays/
# /community/
# /community/diversity/
# /community/lists/
# /community/irc/
# /community/forums/
# /psf/annual-report/2021/
# /community/workshops/
# /community/sigs/
# /community/logos/
# ...

# %% [markdown]
# # To Download The CSV Of the URL

# %%
import csv
csv_filename = "urls.csv"
with open(csv_filename, 'w', newline='') as csv_file:
    csv_writer = csv.writer(csv_file)
    for url in url:
        csv_writer.writerow([url])

# %%
soup_1 = BeautifulSoup(response_python_org.text, "html.parser")

# %% [markdown]
# b. list of all the h1, h2, h3 tags from the webpage

# %%
h1tags=soup_1.find_all('h1')
for soup_1 in h1tags:
  print(soup_1)
# Out:
# <h1 class="site-headline">
# <a href="/"><img alt="python™" class="python-logo" src="/static/img/python-logo.png"/></a>
# </h1>
# <h1>Functions Defined</h1>
# <h1>Compound Data Types</h1>
# <h1>Intuitive Interpretation</h1>
# <h1>All the Flow You’d Expect</h1>
# <h1>Quick &amp; Easy to Learn</h1>

# %%
h2tags=soup_1.find_all('h2')
for soup_1 in h2tags:
  print(soup_1)

# %%
h3tags=soup_1.find_all('h3')
for soup_1 in h3tags:
  print(soup_1)

# %% [markdown]
# c. extract all the text from the given web page

# %%
all_text = soup_1.get_text()
print(all_text)
# Out:
# Quick & Easy to Learn

# %% [markdown]
# d. find and print all li tags of a given web page.

# %%
li_tags=soup_1.find_all("li")
for li in li_tags:
  print(li)

# %% [markdown]
# # Task 2: Data Cleaning
# Dataset: Zomato missing value dataset

# %%
import numpy as np
import pandas as pd
from sklearn.impute import KNNImputer

# %% [markdown]
# Reading the Datasets

# %%
df=pd.read_csv('/content/zomato_dataset.csv')
df=pd.DataFrame(df)
df.head()
# Out:
#    Restaurant ID   Restaurant Name Country Code              City  \
# 0        6317637  Le Petit Souffle          162       Makati City
# 1        6304287  Izakaya Kikufuji          162       Makati City
# 2        6300002                 ?          162                 ?
# 3        6318506              Ooma            ?                 ?
# 4        6314302                 ?            ?  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor; Century City Mall; Kalayaan Avenu...
# 1  Little Tokyo; 2277 Chino Roces Avenue; Legaspi...
# 2  Edsa Shangri-La; 1 Garden Way; Ortigas; Mandal...
# 3  Third Floor; Mega Fashion Hall; SM Megamall; O...
# 4  Third Floor; Mega Atrium; SM Megamall; Ortigas...
#
#                                      Locality  \
# 0   Century City Mall; Poblacion; Makati City
# 1  Little Tokyo; Legaspi Village; Makati City
# 2  Edsa Shangri-La; Ortigas; Mandaluyong City
# 3                                           ?
# ...

# %% [markdown]
# As we can see the there are no null values but we can see there are ? so we have to map the ? with np.nan which is using null values

# %% [markdown]
# Finding the missing data

# %%
mapping={'?':np.nan}
df.replace({'Restaurant ID':mapping,'Restaurant Name':mapping,'Country Code':mapping,
             'City':mapping,'Address':mapping,'Locality':mapping,
             'Locality Verbose':mapping,'Longitude':mapping,'Latitude':mapping,
             'Cuisines':mapping,'Average Cost for two':mapping,'Currency':mapping,
             'Price range':mapping,'Aggregate rating':mapping,'Rating color':mapping,
             'Rating text':mapping,'Votes':mapping},inplace=True)

# %%
df.isnull().sum()
# Out:
# Restaurant ID              0
# Restaurant Name         4985
# Country Code            4972
# City                    4840
# Address                 4855
# Locality                4828
# Locality Verbose        4974
# Longitude               4911
# Latitude                4855
# Cuisines                4932
# Average Cost for two    4893
# Currency                4894
# Price range             4931
# Aggregate rating        4861
# Rating color            4935
# Rating text             4965
# Votes                   4918
# dtype: int64

# %% [markdown]
# Now due to mapping we can see there are some missing values containing in the zomato dataset
# # Imputing the Dataset which contains numerical features

# %%
df.head()
# Out:
#    Restaurant ID   Restaurant Name Country Code              City  \
# 0        6317637  Le Petit Souffle          162       Makati City
# 1        6304287  Izakaya Kikufuji          162       Makati City
# 2        6300002               NaN          162               NaN
# 3        6318506              Ooma          NaN               NaN
# 4        6314302               NaN          NaN  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor; Century City Mall; Kalayaan Avenu...
# 1  Little Tokyo; 2277 Chino Roces Avenue; Legaspi...
# 2  Edsa Shangri-La; 1 Garden Way; Ortigas; Mandal...
# 3  Third Floor; Mega Fashion Hall; SM Megamall; O...
# 4  Third Floor; Mega Atrium; SM Megamall; Ortigas...
#
#                                      Locality  \
# 0   Century City Mall; Poblacion; Makati City
# 1  Little Tokyo; Legaspi Village; Makati City
# 2  Edsa Shangri-La; Ortigas; Mandaluyong City
# 3                                         NaN
# ...

# %% [markdown]
# Numerical Data are country code,latitude,longitude,aggregrate rating,votes we will apply knn imputer on the following data till 5 nearest neighbour

# %%
features_to_impute = ['Restaurant ID', 'Country Code','Longitude','Latitude','Aggregate rating','Votes','Price range']

# %%
imputer = KNNImputer(n_neighbors=5)

# %%
imputed_features = imputer.fit_transform(df[features_to_impute])
imputed_df = pd.DataFrame(imputed_features, columns=features_to_impute)
non_imputed_columns = [col for col in df.columns if col not in features_to_impute]
for col in non_imputed_columns:
    imputed_df[col] = df[col]

# %%
imputed_df.head()
# Out:
#    Restaurant ID  Country Code   Longitude   Latitude  Aggregate rating  \
# 0      6317637.0         162.0  121.027535  14.565443              4.80
# 1      6304287.0         162.0  121.014101  14.553708              4.50
# 2      6300002.0         162.0  121.018175  14.581404              4.40
# 3      6318506.0         162.0  121.056475  14.486936              4.90
# 4      6314302.0         162.0  121.055356  14.565577              4.66
#
#    Votes  Price range   Restaurant Name              City  \
# 0  314.0          3.0  Le Petit Souffle       Makati City
# 1  591.0          3.0  Izakaya Kikufuji       Makati City
# 2  270.0          3.6               NaN               NaN
# 3  365.0          4.0              Ooma               NaN
# 4  229.0          4.0               NaN  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor; Century City Mall; Kalayaan Avenu...
# 1  Little Tokyo; 2277 Chino Roces Avenue; Legaspi...
# ...

# %%
imputed_df.isnull().sum()
# Out:
# Restaurant ID              0
# Country Code               0
# Longitude                  0
# Latitude                   0
# Aggregate rating           0
# Votes                      0
# Price range                0
# Restaurant Name         4985
# City                    4840
# Address                 4855
# Locality                4828
# Locality Verbose        4974
# Cuisines                4932
# Average Cost for two    4893
# Currency                4894
# Rating color            4935
# Rating text             4965
# dtype: int64

# %%
imputed_df['City'].fillna(method='bfill',inplace=True)
imputed_df['Address'].fillna(method='ffill',inplace=True)
imputed_df['Restaurant Name'].fillna(method='ffill',inplace=True)
imputed_df['Locality'].fillna(method='bfill',inplace=True)
imputed_df['Locality Verbose'].fillna(method='ffill',inplace=True)
imputed_df['Locality'].fillna(method='bfill',inplace=True)
imputed_df['Cuisines'].fillna(method='ffill',inplace=True)
imputed_df['Rating color'].fillna(method='bfill',inplace=True)
imputed_df['Currency'].fillna(method='ffill',inplace=True)
imputed_df['Rating text'].fillna(method='bfill',inplace=True)
imputed_df['Average Cost for two'].fillna(method='ffill',inplace=True)

# %%
imputed_df.isnull().sum()
# Out:
# Restaurant ID           0
# Country Code            0
# Longitude               0
# Latitude                0
# Aggregate rating        0
# Votes                   0
# Price range             0
# Restaurant Name         0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Rating color            0
# Rating text             0
# dtype: int64

# %% [markdown]
# # A.Min-Max scaling

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
numeric_columns = imputed_df.select_dtypes(include=['float64', 'int64']).columns
min_max_scaler = MinMaxScaler()
data_minmax_scaled = min_max_scaler.fit_transform(imputed_df[numeric_columns])
data_minmax_scaled = pd.DataFrame(data_minmax_scaled, columns=numeric_columns)

# %%
data_minmax_scaled.head()
# Out:
#    Restaurant ID  Country Code  Longitude  Latitude  Aggregate rating  \
# 0       0.341480      0.748837   0.838318  0.574275          0.979592
# 1       0.340758      0.748837   0.838278  0.574155          0.918367
# 2       0.340527      0.748837   0.838290  0.574440          0.897959
# 3       0.341527      0.748837   0.838405  0.573468          1.000000
# 4       0.341300      0.748837   0.838402  0.574277          0.951020
#
#       Votes  Price range
# 0  0.039591     0.666667
# 1  0.074518     0.666667
# 2  0.034044     0.866667
# 3  0.046022     1.000000
# 4  0.028874     1.000000

# %% [markdown]
# # 2.Z score scaling

# %%
z_scaler = StandardScaler()
data_zscore_scaled = z_scaler.fit_transform(imputed_df[numeric_columns])
data_zscore_scaled = pd.DataFrame(data_zscore_scaled, columns=numeric_columns)

# %%
data_zscore_scaled.head()
# Out:
#    Restaurant ID  Country Code  Longitude  Latitude  Aggregate rating  \
# 0      -0.310940      2.581819   1.425014 -1.142256          1.616692
# 1      -0.312458      2.581819   1.424677 -1.143421          1.390861
# 2      -0.312946      2.581819   1.424779 -1.140670          1.315584
# 3      -0.310841      2.581819   1.425738 -1.150052          1.691969
# 4      -0.311319      2.581819   1.425710 -1.142242          1.511304
#
#       Votes  Price range
# 0  0.421556     1.594417
# 1  1.180956     1.594417
# 2  0.300929     2.385688
# 3  0.561373     2.913201
# 4  0.188527     2.913201

# %% [markdown]
# # Task 3: Data Wrangling
# Dataset: Video games dataset and Windmill dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.impute import KNNImputer

# %% [markdown]
# 1. Find missing values

# %%
data=pd.read_csv('/content/Video_Game_Sales_dataset.csv')

# %%
data=pd.DataFrame(data)

# %%
data.isnull().sum()
# Out:
# Name                  0
# Platform              0
# Year_of_Release       8
# Genre                 0
# Publisher             1
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       9080
# Critic_Count       9080
# User_Score         9618
# User_Count         9618
# Rating             7164
# dtype: int64

# %% [markdown]
# 2. Fill missing values using k-nn imputation techniques

# %%
numerical_features = data.select_dtypes(include=['int64', 'float64']).columns
imputer = KNNImputer(n_neighbors=5)
data_imputed = data.copy()
data_imputed[numerical_features] = imputer.fit_transform(data[numerical_features])
data_1=data_imputed[numerical_features]
data_1.head()
# Out:
#    Year_of_Release  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0           2006.0     41.36     28.96      3.77         8.45         82.54
# 1           1985.0     29.08      3.58      6.81         0.77         40.24
# 2           2008.0     15.68     12.80      3.79         3.29         35.57
# 3           2009.0     15.61     10.95      3.28         2.95         32.78
# 4           1996.0     11.27      8.89     10.22         1.00         31.37
#
#    Critic_Score  Critic_Count  User_Score  User_Count
# 0          76.0          51.0        8.00       324.0
# 1          79.2          66.4        7.96       412.4
# 2          82.0          73.0        8.30       712.0
# 3          80.0          73.0        8.00       193.0
# 4          81.4          64.6        8.08       466.8

# %% [markdown]
# 3. Select all the Sports video games from the video games dataset.

# %%
sports_genre = data[data['Genre'] == 'Sports']
sports_genre.head()
# Out:
#                  Name Platform  Year_of_Release   Genre        Publisher  \
# 0          Wii Sports      Wii           2006.0  Sports         Nintendo
# 3   Wii Sports Resort      Wii           2009.0  Sports         Nintendo
# 13            Wii Fit      Wii           2007.0  Sports         Nintendo
# 15       Wii Fit Plus      Wii           2009.0  Sports         Nintendo
# 75            FIFA 17      PS4           2016.0  Sports  Electronic Arts
#
#     NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0      41.36     28.96      3.77         8.45         82.54          76.0
# 3      15.61     10.95      3.28         2.95         32.78          80.0
# 13      8.92      8.03      3.60         2.15         22.70          80.0
# 15      9.01      8.49      2.53         1.77         21.79          80.0
# 75      0.90      6.75      0.09         1.33          9.07          85.0
#
#     Critic_Count  User_Score  User_Count Rating
# ...

# %% [markdown]
# 4. Which video games had global sales greater than 50?

# %%
gamer_greater=data[data['Global_Sales']>50]
gamer_greater
# Out:
#          Name Platform  Year_of_Release   Genre Publisher  NA_Sales  EU_Sales  \
# 0  Wii Sports      Wii           2006.0  Sports  Nintendo     41.36     28.96
#
#    JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 0      3.77         8.45         82.54          76.0          51.0
#
#    User_Score  User_Count Rating
# 0         8.0       324.0      E

# %% [markdown]
# 5. Load the video games dataframe in descending order by Name

# %%
desc_name=data.sort_values(by='Name', ascending=False)
desc_name.head(5)
# Out:
#                                Name Platform  Year_of_Release     Genre  \
# 480      wwe Smackdown vs. Raw 2006      PS2           2005.0  Fighting
# 8285   uDraw Studio: Instant Artist      Wii           2011.0      Misc
# 15696  uDraw Studio: Instant Artist     X360           2011.0      Misc
# 645                    uDraw Studio      Wii           2010.0      Misc
# 16593    thinkSMART: Chess for Kids       DS           2011.0      Misc
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 480                   THQ      1.57      1.02       0.0         0.41
# 8285                  THQ      0.06      0.09       0.0         0.02
# 15696                 THQ      0.01      0.01       0.0         0.00
# 645                   THQ      1.65      0.57       0.0         0.20
# 16593  Mentor Interactive      0.01      0.00       0.0         0.00
#
#        Global_Sales  Critic_Score  Critic_Count  User_Score  User_Count Rating
# ...

# %% [markdown]
# 6. What genre games have been made the most?

# %%
genre_most=data['Genre'].value_counts().idxmax()
genre_most
# Out:
# 'Action'

# %% [markdown]
# 7. Which year had the most game release?

# %%
release_most=data['Year_of_Release'].value_counts()
most_year=release_most.idxmax()
most_year
# Out:
# 2009.0

# %% [markdown]
# 8. Which year had the highest sales worldwide?

# %%
years_sale=data.groupby('Year_of_Release')['Global_Sales'].sum()
years_most=years_sale.idxmax()
years_most
# Out:
# 2008.0

# %% [markdown]
# 9. Which genre game has been released the most in a single year?

# %%
genre_year=data.groupby('Genre')['Year_of_Release'].value_counts()
genre_year
# Out:
# Genre     Year_of_Release
# Action    2015.0             284
#           2009.0             283
#           2012.0             277
#           2011.0             260
#           2008.0             235
#                             ...
# Strategy  2014.0              10
#           1994.0               6
#           1991.0               4
#           1992.0               3
#           1993.0               2
# Name: Year_of_Release, Length: 400, dtype: int64

# %% [markdown]
# 10. Which genre game has the highest sale price globally?

# %%
high_global=data.sort_values('Global_Sales',ascending=False)
high_global.head(1)
# Out:
#          Name Platform  Year_of_Release   Genre Publisher  NA_Sales  EU_Sales  \
# 0  Wii Sports      Wii           2006.0  Sports  Nintendo     41.36     28.96
#
#    JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 0      3.77         8.45         82.54          76.0          51.0
#
#    User_Score  User_Count Rating
# 0         8.0       324.0      E

# %% [markdown]
# # Wind Mill DataSet

# %% [markdown]
# 11. Plot a scatter plot of Wind speed vs Power Output

# %%
df1=pd.read_excel('/content/Windmill Dataset.xlsx')
df1
# Out:
#     Windmill  Wind Speed (m/s)  Power output (MW)
# 0         a1          1.096875           0.000000
# 1         a2          1.231528           0.000000
# 2         a3          1.275139           0.005479
# 3         a4          1.365486           0.010104
# 4         a5          1.387778           0.010812
# ..       ...               ...                ...
# 360     a361         15.247639          27.502063
# 361     a362         15.267847          28.577500
# 362     a363         16.346944          29.009979
# 363     a364         16.575833          22.852229
# 364     a365         18.316389          29.020937
#
# [365 rows x 3 columns]

# %%
df1=pd.DataFrame(df1)
df1.head()
# Out:
#   Windmill  Wind Speed (m/s)  Power output (MW)
# 0       a1          1.096875           0.000000
# 1       a2          1.231528           0.000000
# 2       a3          1.275139           0.005479
# 3       a4          1.365486           0.010104
# 4       a5          1.387778           0.010812

# %%
df1.isnull().sum()
# Out:
# Windmill             0
# Wind Speed (m/s)     0
# Power output (MW)    0
# dtype: int64

# %%
plt.scatter(df1['Wind Speed (m/s)'],df1['Power output (MW)'])
plt.show()

# %% [markdown]
# 12. Which windmill had maximum and minimum windspeed?

# %%
max_wind=np.max(df1['Wind Speed (m/s)'])
print(max_wind)
# Out:
# 18.316388889

# %%
min_wind=np.min(df1['Wind Speed (m/s)'])
print(min_wind)
# Out:
# 1.096875

# %% [markdown]
# 13. Which windmill had maximum and minimum power output

# %%
max_pow=np.max(df1['Power output (MW)'])
print(max_pow)
# Out:
# 29.0209375

# %%
min_pow=np.min(df1['Power output (MW)'])
print(min_pow)
# Out:
# 0.0
