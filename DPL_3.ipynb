# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/Data Cleaning_part1_dataset_movie scores.csv')

# %%
df
# Out:
#   first_name last_name   age Gender  pre_movie_score  post_movie_score
# 0       Root      Joss  36.0      m              8.0               9.0
# 1        NaN       NaN   NaN    NaN              NaN               NaN
# 2      Stark      Mike  48.0      m              NaN               NaN
# 3      Sofie    Miller  39.0      f              7.0               8.0
# 4       Emma       Roy  84.0      f              6.0               8.0

# %% [markdown]
# with the help of isnull() we can find null values NAN in the dataset it gives true for missing value
# there is a function not null which missing value written false

# %%
df.isnull()
# Out:
#    first_name  last_name    age  Gender  pre_movie_score  post_movie_score
# 0       False      False  False   False            False             False
# 1        True       True   True    True             True              True
# 2       False      False  False   False             True              True
# 3       False      False  False   False            False             False
# 4       False      False  False   False            False             False

# %%
df.notnull()
# Out:
#    first_name  last_name    age  Gender  pre_movie_score  post_movie_score
# 0        True       True   True    True             True              True
# 1       False      False  False   False            False             False
# 2        True       True   True    True            False             False
# 3        True       True   True    True             True              True
# 4        True       True   True    True             True              True

# %%
df[df['first_name'].notnull()]
# Out:
#   first_name last_name   age Gender  pre_movie_score  post_movie_score
# 0       Root      Joss  36.0      m              8.0               9.0
# 2      Stark      Mike  48.0      m              NaN               NaN
# 3      Sofie    Miller  39.0      f              7.0               8.0
# 4       Emma       Roy  84.0      f              6.0               8.0

# %%
df[(df['pre_movie_score'].isnull()) & df['Gender'].notnull()]
# Out:
#   first_name last_name   age Gender  pre_movie_score  post_movie_score
# 2      Stark      Mike  48.0      m              NaN               NaN

# %% [markdown]
# How to drop or replace null values?

# %% [markdown]
# count of missing value

# %%
df.isna().sum().sum()
# Out:
# 8

# %% [markdown]
# Drop rows containing null values
# 0 is for rows or index will drop row null values
# 1 is for columns of index and drop columns null values

# %%
df1=df.dropna(axis=0)

# %%
df1
# Out:
#   first_name last_name   age Gender  pre_movie_score  post_movie_score
# 0       Root      Joss  36.0      m              8.0               9.0
# 3      Sofie    Miller  39.0      f              7.0               8.0
# 4       Emma       Roy  84.0      f              6.0               8.0

# %%
df1.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# Drop Column Containing null values

# %%
df2=df.dropna(axis=1)

# %%
df2
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %% [markdown]
# threshint required many non na vALUES

# %%
df3=df.dropna(thresh=2)

# %%
df3
# Out:
#   first_name last_name   age Gender  pre_movie_score  post_movie_score
# 0       Root      Joss  36.0      m              8.0               9.0
# 2      Stark      Mike  48.0      m              NaN               NaN
# 3      Sofie    Miller  39.0      f              7.0               8.0
# 4       Emma       Roy  84.0      f              6.0               8.0

# %%
df4=df.dropna(thresh=2,axis=1)

# %%
df4
# Out:
#   first_name last_name   age Gender  pre_movie_score  post_movie_score
# 0       Root      Joss  36.0      m              8.0               9.0
# 1        NaN       NaN   NaN    NaN              NaN               NaN
# 2      Stark      Mike  48.0      m              NaN               NaN
# 3      Sofie    Miller  39.0      f              7.0               8.0
# 4       Emma       Roy  84.0      f              6.0               8.0

# %% [markdown]
# replacing missing values with fillna

# %%
df.fillna("NEW")
# Out:
#   first_name last_name   age Gender pre_movie_score post_movie_score
# 0       Root      Joss  36.0      m             8.0              9.0
# 1        NEW       NEW   NEW    NEW             NEW              NEW
# 2      Stark      Mike  48.0      m             NEW              NEW
# 3      Sofie    Miller  39.0      f             7.0              8.0
# 4       Emma       Roy  84.0      f             6.0              8.0

# %%
age1=df['age'].mean()

# %%
age2=age1.round()

# %%
df['age'].fillna(age2)
# Out:
# 0    36.00
# 1    51.75
# 2    48.00
# 3    39.00
# 4    84.00
# Name: age, dtype: float64

# %%
df
# Out:
#   first_name last_name    age Gender  pre_movie_score  post_movie_score
# 0       Root      Joss  36.00      m              8.0          9.000000
# 1      Empty       NaN  51.75    NaN              7.0          8.333333
# 2      Stark      Mike  48.00      m              7.0          8.333333
# 3      Sofie    Miller  39.00      f              7.0          8.000000
# 4       Emma       Roy  84.00      f              6.0          8.000000

# %%
df['first_name']
# Out:
# 0     Root
# 1    Empty
# 2    Stark
# 3    Sofie
# 4     Emma
# Name: first_name, dtype: object

# %%
df['first_name']=df['first_name'].fillna("Empty")

# %%
df
# Out:
#   first_name last_name    age Gender  pre_movie_score  post_movie_score
# 0       Root      Joss  36.00      m              8.0          9.000000
# 1      Empty       NaN  51.75    NaN              7.0          8.333333
# 2      Stark      Mike  48.00      m              7.0          8.333333
# 3      Sofie    Miller  39.00      f              7.0          8.000000
# 4       Emma       Roy  84.00      f              6.0          8.000000

# %%
df['pre_movie_score'].mean()
# Out:
# 7.0

# %%
df['pre_movie_score'].fillna(df['pre_movie_score'].mean(),inplace=True)

# %%
df
# Out:
#   first_name last_name    age Gender  pre_movie_score  post_movie_score
# 0       Root      Joss  36.00      m              8.0          9.000000
# 1      Empty       NaN  51.75    NaN              7.0          8.333333
# 2      Stark      Mike  48.00      m              7.0          8.333333
# 3      Sofie    Miller  39.00      f              7.0          8.000000
# 4       Emma       Roy  84.00      f              6.0          8.000000

# %%
df['post_movie_score'].fillna(df['post_movie_score'].mean(),inplace=True)

# %%
df
# Out:
#   first_name last_name    age Gender  pre_movie_score  post_movie_score
# 0       Root      Joss  36.00      m              8.0          9.000000
# 1      Empty       NaN  51.75    NaN              7.0          8.333333
# 2      Stark      Mike  48.00      m              7.0          8.333333
# 3      Sofie    Miller  39.00      f              7.0          8.000000
# 4       Emma       Roy  84.00      f              6.0          8.000000

# %%
dz=pd.read_csv("/content/Data Cleaning_part1_dataset_Students_expenses.csv")

# %%
dz
# Out:
#    Expenses  Riya  Samual   Neeti  Shreya
# 0   January  8100  6200.0  9200.0  8150.0
# 1  February  9500  7500.0     NaN  7200.0
# 2     March  7300  6100.0  8800.0  8100.0
# 3     April  7800  7200.0  8900.0  7500.0
# 4       May  8500     NaN  9100.0  7800.0
# 5      June  9200  7100.0  8850.0     NaN

# %%
dz.isnull()
# Out:
#    Expenses   Riya  Samual  Neeti  Shreya
# 0     False  False   False  False   False
# 1     False  False   False   True   False
# 2     False  False   False  False   False
# 3     False  False   False  False   False
# 4     False  False    True  False   False
# 5     False  False   False  False    True

# %%
dz.notnull()
# Out:
#    Expenses  Riya  Samual  Neeti  Shreya
# 0      True  True    True   True    True
# 1      True  True    True  False    True
# 2      True  True    True   True    True
# 3      True  True    True   True    True
# 4      True  True   False   True    True
# 5      True  True    True   True   False

# %%
dz.isna().sum()
# Out:
# Expenses    0
# Riya        0
# Samual      1
# Neeti       1
# Shreya      1
# dtype: int64

# %%
dz.isna().sum().sum()
# Out:
# 3

# %%
dz['Samual'].fillna(dz['Samual'].mean(),inplace=True)

# %%
dz
# Out:
#    Expenses  Riya  Samual   Neeti  Shreya
# 0   January  8100  6200.0  9200.0  8150.0
# 1  February  9500  7500.0     NaN  7200.0
# 2     March  7300  6100.0  8800.0  8100.0
# 3     April  7800  7200.0  8900.0  7500.0
# 4       May  8500  6820.0  9100.0  7800.0
# 5      June  9200  7100.0  8850.0     NaN

# %%
dz['Neeti'].fillna(dz['Neeti'].mean(),inplace=True)

# %%
dz['Shreya'].fillna(dz['Shreya'].mean(),inplace=True)

# %%
dz
# Out:
#    Expenses  Riya  Samual   Neeti  Shreya
# 0   January  8100  6200.0  9200.0  8150.0
# 1  February  9500  7500.0  8970.0  7200.0
# 2     March  7300  6100.0  8800.0  8100.0
# 3     April  7800  7200.0  8900.0  7500.0
# 4       May  8500  6820.0  9100.0  7800.0
# 5      June  9200  7100.0  8850.0  7750.0

# %%
dz.median()
# Out:
# <ipython-input-122-98d6a6046c6f>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dz.median()
# Riya      8300.0
# Samual    6960.0
# Neeti     8935.0
# Shreya    7775.0
# dtype: float64

# %%
dz.fillna(dz.median())
# Out:
# <ipython-input-123-990a3f9ae3fa>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dz.fillna(dz.median())
#    Expenses  Riya  Samual   Neeti  Shreya
# 0   January  8100  6200.0  9200.0  8150.0
# 1  February  9500  7500.0  8970.0  7200.0
# 2     March  7300  6100.0  8800.0  8100.0
# 3     April  7800  7200.0  8900.0  7500.0
# 4       May  8500  6820.0  9100.0  7800.0
# 5      June  9200  7100.0  8850.0  7750.0
